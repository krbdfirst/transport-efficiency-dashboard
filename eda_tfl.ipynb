# %% [markdown]
# <a href="https://colab.research.google.com/github/krbdfirst/transport-efficiency-dashboard/blob/main/eda_tfl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests #The is important to use REST API
import pandas as pd
import json

# %%
tfl_api_id = "5468f533677b4d3b851a99041b968f92"
tfl_api_key = "89b9366ea4604282bab39e8b44d26550"
modes = "bus"
url = f"https://api.tfl.gov.uk/Line/Mode/{modes}/Disruption?app_id={tfl_api_id}&app_key={tfl_api_key}"

response = requests.get(url)
data = response.json()
print(data)
# Out:
# [{'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities', 'category': 'Information', 'type': 'stopInfo', 'categoryDescription': 'Information', 'description': 'Middle Park Avenue / Westhorne Avenue stop WK is not served by Route 160 on schooldays between 1500 and 1630, please use the previous stop at Eltham Green School.', 'created': '2024-08-12T11:10:00Z', 'lastUpdate': '2024-08-12T11:12:00Z', 'affectedRoutes': [], 'affectedStops': []}, {'$type': 'Tfl.Api.Presentation.Entities.Disruption, Tfl.Api.Presentation.Entities', 'category': 'Information', 'type': 'stopInfo', 'categoryDescription': 'Information', 'description': 'BEAR ROAD FLYOVER: Bus stops on Route 290 are located on the Country Way flyover and are only accessible via stairs to and from the Route 111 and H25 stops in Bear Road.', 'created': '2024-09-02T10:06:00Z', 'lastUpdate': '2024-09-02T10:09:00Z', 'affectedRoutes': [], 'affectedStops': []}, {'$type': 'Tfl.Api.Presentation.Entities.Disruption, T
# ...

# %%
tfl_api_id = "5468f533677b4d3b851a99041b968f92"
tfl_api_key = "89b9366ea4604282bab39e8b44d26550"
url= f"https://api.tfl.gov.uk/Line/Meta/Modes?app_id={tfl_api_id}&app_key={tfl_api_key}"
response = requests.get(url)
data = response.json()
df = pd.json_normalize(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   $type               18 non-null     object
#  1   isTflService        18 non-null     bool
#  2   isFarePaying        18 non-null     bool
#  3   isScheduledService  18 non-null     bool
#  4   modeName            18 non-null     object
# dtypes: bool(3), object(2)
# memory usage: 474.0+ bytes

# %%
agency = pd.read_csv("")
agency.info()
